# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
# Out:
# 2025-08-23 05:05:12.001506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755925512.345771      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755925512.442357      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# ----------------------
# 1. Load and preprocess
# ----------------------
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

X_train, X_test = X_train / 255.0, X_test / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test  = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train)

# %%
# ---------------------
# 2. Build CNN Model
# ---------------------
def build_model():
    model = models.Sequential([
        # Block 1
        layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.25),

        # Block 2
        layers.Conv2D(64, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(128, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.25),

        # Dense Layers
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])

    # Adam with weight decay (AdamW) - better generalization
    optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4)

    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model = build_model()
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1755925559.709081      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1755925559.709745      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 30, 30, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 15, 15, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 15, 15, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 13, 13, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 558,634 (2.13 MB)
#  Trainable params: 556,714 (2.12 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# ----------------------
# 3. Callbacks
# ----------------------
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1)
]

# %%
# ----------------------
# 4. Train
# ----------------------
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    validation_data=(X_test, y_test),
    epochs=80,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.3424 - loss: 1.9780 - val_accuracy: 0.4987 - val_loss: 1.4669 - learning_rate: 0.0010
# Epoch 2/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.5277 - loss: 1.3188 - val_accuracy: 0.4829 - val_loss: 1.7414 - learning_rate: 0.0010
# Epoch 3/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.6092 - loss: 1.0991 - val_accuracy: 0.6808 - val_loss: 0.9311 - learning_rate: 0.0010
# Epoch 4/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.6568 - loss: 0.9839 - val_accuracy: 0.7037 - val_loss: 0.8759 - learning_rate: 0.0010
# Epoch 5/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.6878 - loss: 0.8936 - val_accuracy: 0.7087 - val_loss: 0.8833 - learning_rate: 0.0010
# Epoch 6/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.7108 - loss: 0.8368 - val_accuracy: 0.7372 - val_loss: 0.7835 - learning_rate: 0.0010
# Epoch 7/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.7237 - loss: 0.7948 - val_accuracy: 0.7386 - val_loss: 0.7735 - learning_rate: 0.0010
# Epoch 8/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.7301 - loss: 0.7730 - val_accuracy: 0.7667 - val_loss: 0.6964 - learning_rate: 0.0010
# Epoch 9/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.7466 - loss: 0.7285 - val_accuracy: 0.7452 - val_loss: 0.7623 - learning_rate: 0.0010
# Epoch 10/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.7926 - loss: 0.6016 - val_accuracy: 0.7835 - val_loss: 0.6653 - learning_rate: 0.0010
# Epoch 16/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.7922 - loss: 0.5953 - val_accuracy: 0.7790 - val_loss: 0.6469 - learning_rate: 0.0010
# Epoch 17/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.7994 - loss: 0.5859 - val_accuracy: 0.8277 - val_loss: 0.5156 - learning_rate: 0.0010
# Epoch 18/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8023 - loss: 0.5696 - val_accuracy: 0.8206 - val_loss: 0.5244 - learning_rate: 0.0010
# Epoch 19/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8008 - loss: 0.5743 - val_accuracy: 0.8247 - val_loss: 0.5211 - learning_rate: 0.0010
# Epoch 20/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.8129 - loss: 0.5511 - val_accuracy: 0.8207 - val_loss: 0.5345 - learning_rate: 0.0010
# Epoch 21/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8092 - loss: 0.5576 - val_accuracy: 0.8176 - val_loss: 0.5460 - learning_rate: 0.0010
# Epoch 22/80
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8171 - loss: 0.5290
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8171 - loss: 0.5290 - val_accuracy: 0.8189 - val_loss: 0.5468 - learning_rate: 0.0010
# Epoch 23/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8263 - loss: 0.5013 - val_accuracy: 0.8360 - val_loss: 0.4903 - learning_rate: 5.0000e-04
# Epoch 24/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8343 - loss: 0.4782 - val_accuracy: 0.8453 - val_loss: 0.4572 - learning_rate: 5.0000e-04
# Epoch 25/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8360 - loss: 0.4789 - val_accuracy: 0.8339 - val_loss: 0.4904 - learning_rate: 5.0000e-04
# Epoch 26/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8401 - loss: 0.4618 - val_accuracy: 0.8454 - val_loss: 0.4641 - learning_rate: 5.0000e-04
# Epoch 27/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8390 - loss: 0.4645 - val_accuracy: 0.8358 - val_loss: 0.4804 - learning_rate: 5.0000e-04
# Epoch 28/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8409 - loss: 0.4625 - val_accuracy: 0.8327 - val_loss: 0.5038 - learning_rate: 5.0000e-04
# Epoch 29/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8438 - loss: 0.4451 - val_accuracy: 0.8504 - val_loss: 0.4357 - learning_rate: 5.0000e-04
# Epoch 30/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 34ms/step - accuracy: 0.8446 - loss: 0.4475 - val_accuracy: 0.8503 - val_loss: 0.4452 - learning_rate: 5.0000e-04
# Epoch 31/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 34ms/step - accuracy: 0.8456 - loss: 0.4462 - val_accuracy: 0.8257 - val_loss: 0.5273 - learning_rate: 5.0000e-04
# Epoch 32/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.8468 - loss: 0.4432 - val_accuracy: 0.8517 - val_loss: 0.4536 - learning_rate: 5.0000e-04
# Epoch 33/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 34ms/step - accuracy: 0.8475 - loss: 0.4472 - val_accuracy: 0.8599 - val_loss: 0.4235 - learning_rate: 5.0000e-04
# Epoch 34/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8483 - loss: 0.4350 - val_accuracy: 0.8521 - val_loss: 0.4498 - learning_rate: 5.0000e-04
# Epoch 35/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8483 - loss: 0.4324 - val_accuracy: 0.8523 - val_loss: 0.4442 - learning_rate: 5.0000e-04
# Epoch 36/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8552 - loss: 0.4221 - val_accuracy: 0.8485 - val_loss: 0.4472 - learning_rate: 5.0000e-04
# Epoch 37/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8523 - loss: 0.4254 - val_accuracy: 0.8466 - val_loss: 0.4614 - learning_rate: 5.0000e-04
# Epoch 38/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8563 - loss: 0.4161
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8563 - loss: 0.4162 - val_accuracy: 0.8587 - val_loss: 0.4185 - learning_rate: 5.0000e-04
# Epoch 39/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8572 - loss: 0.4123 - val_accuracy: 0.8593 - val_loss: 0.4184 - learning_rate: 2.5000e-04
# Epoch 40/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8638 - loss: 0.3975 - val_accuracy: 0.8628 - val_loss: 0.4067 - learning_rate: 2.5000e-04
# Epoch 41/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8615 - loss: 0.3975 - val_accuracy: 0.8625 - val_loss: 0.4152 - learning_rate: 2.5000e-04
# Epoch 42/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8631 - loss: 0.3927 - val_accuracy: 0.8663 - val_loss: 0.4017 - learning_rate: 2.5000e-04
# Epoch 43/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8668 - loss: 0.3846 - val_accuracy: 0.8647 - val_loss: 0.4050 - learning_rate: 2.5000e-04
# Epoch 44/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8659 - loss: 0.3893 - val_accuracy: 0.8692 - val_loss: 0.3983 - learning_rate: 2.5000e-04
# Epoch 45/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8664 - loss: 0.3937 - val_accuracy: 0.8625 - val_loss: 0.4108 - learning_rate: 2.5000e-04
# Epoch 46/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8665 - loss: 0.3841 - val_accuracy: 0.8682 - val_loss: 0.3935 - learning_rate: 2.5000e-04
# Epoch 47/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8661 - loss: 0.3822 - val_accuracy: 0.8640 - val_loss: 0.4108 - learning_rate: 2.5000e-04
# Epoch 48/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.8643 - loss: 0.3897 - val_accuracy: 0.8633 - val_loss: 0.4182 - learning_rate: 2.5000e-04
# Epoch 49/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8683 - loss: 0.3861
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8683 - loss: 0.3861 - val_accuracy: 0.8655 - val_loss: 0.4173 - learning_rate: 2.5000e-04
# Epoch 50/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8707 - loss: 0.3701 - val_accuracy: 0.8741 - val_loss: 0.3824 - learning_rate: 1.2500e-04
# Epoch 51/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.8723 - loss: 0.3699 - val_accuracy: 0.8728 - val_loss: 0.3929 - learning_rate: 1.2500e-04
# Epoch 52/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.8729 - loss: 0.3671 - val_accuracy: 0.8761 - val_loss: 0.3762 - learning_rate: 1.2500e-04
# Epoch 53/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8724 - loss: 0.3666 - val_accuracy: 0.8714 - val_loss: 0.3906 - learning_rate: 1.2500e-04
# Epoch 54/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8714 - loss: 0.3710 - val_accuracy: 0.8643 - val_loss: 0.4152 - learning_rate: 1.2500e-04
# Epoch 55/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8731 - loss: 0.3626 - val_accuracy: 0.8683 - val_loss: 0.3974 - learning_rate: 1.2500e-04
# Epoch 56/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8729 - loss: 0.3632 - val_accuracy: 0.8726 - val_loss: 0.3920 - learning_rate: 1.2500e-04
# Epoch 57/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8730 - loss: 0.3690
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8730 - loss: 0.3690 - val_accuracy: 0.8734 - val_loss: 0.3908 - learning_rate: 1.2500e-04
# Epoch 58/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8758 - loss: 0.3540 - val_accuracy: 0.8771 - val_loss: 0.3770 - learning_rate: 6.2500e-05
# Epoch 59/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8756 - loss: 0.3512 - val_accuracy: 0.8756 - val_loss: 0.3805 - learning_rate: 6.2500e-05
# Epoch 60/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8745 - loss: 0.3616 - val_accuracy: 0.8721 - val_loss: 0.3950 - learning_rate: 6.2500e-05
# Epoch 61/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8778 - loss: 0.3500 - val_accuracy: 0.8738 - val_loss: 0.3844 - learning_rate: 6.2500e-05
# Epoch 62/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8747 - loss: 0.3570 - val_accuracy: 0.8722 - val_loss: 0.3867 - learning_rate: 6.2500e-05
# Epoch 63/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8822 - loss: 0.3452
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8822 - loss: 0.3453 - val_accuracy: 0.8766 - val_loss: 0.3788 - learning_rate: 6.2500e-05
# Epoch 64/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8790 - loss: 0.3498 - val_accuracy: 0.8739 - val_loss: 0.3859 - learning_rate: 3.1250e-05
# Epoch 65/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8777 - loss: 0.3512 - val_accuracy: 0.8769 - val_loss: 0.3799 - learning_rate: 3.1250e-05
# Epoch 66/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.8787 - loss: 0.3519 - val_accuracy: 0.8741 - val_loss: 0.3858 - learning_rate: 3.1250e-05
# Epoch 67/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.8799 - loss: 0.3480 - val_accuracy: 0.8744 - val_loss: 0.3827 - learning_rate: 3.1250e-05
# Epoch 68/80
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8780 - loss: 0.3487
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8781 - loss: 0.3487 - val_accuracy: 0.8765 - val_loss: 0.3792 - learning_rate: 3.1250e-05

# %%
# ----------------------
# 5. Evaluation
# ----------------------
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"✅ Test Accuracy: {test_acc*100:.2f}%")

# Plot accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
# Out:
# ✅ Test Accuracy: 87.71%

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Predict on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Define CIFAR-10 class names
class_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer',
    'dog', 'frog', 'horse', 'ship', 'truck'
]

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# Classification Report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     airplane       0.90      0.89      0.89      1000
#   automobile       0.93      0.95      0.94      1000
#         bird       0.90      0.82      0.86      1000
#          cat       0.83      0.69      0.75      1000
#         deer       0.86      0.90      0.88      1000
#          dog       0.88      0.76      0.81      1000
#         frog       0.78      0.97      0.87      1000
#        horse       0.90      0.92      0.91      1000
#         ship       0.94      0.93      0.94      1000
#        truck       0.87      0.95      0.91      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
# ---------------- Project Conclusion ---------------- #
print("📌 Project Summary")
print("="*50)

# Print final evaluation
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Final Test Accuracy : {acc*100:.2f}%")
print(f"Final Test Loss     : {loss:.4f}")

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=class_names))

print("\n🔍 Key Observations:")
print("- Model achieved strong performance with overall accuracy close to 90%.")
print("- Best performing classes: Automobile, Ship, Horse.")
print("- Weakest performance observed in Cat and Dog due to visual similarities.")
print("- Balanced performance across other categories indicates robust learning.")

print("\n✅ Conclusion:")
print("This CNN model demonstrates effective feature extraction and classification "
      "for the CIFAR-10 dataset, achieving reliable accuracy and generalization. "
      "Further improvements could involve data augmentation, deeper architectures "
      "like ResNet, or transfer learning for better fine-grained recognition.")
print("="*50)
print("🎯 Project Completed Successfully!")


# Accuracy plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Training vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# 📌 Project Summary
# ==================================================
# Final Test Accuracy : 87.71%
# Final Test Loss     : 0.3770
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     airplane       0.90      0.89      0.89      1000
#   automobile       0.93      0.95      0.94      1000
#         bird       0.90      0.82      0.86      1000
#          cat       0.83      0.69      0.75      1000
#         deer       0.86      0.90      0.88      1000
#          dog       0.88      0.76      0.81      1000
#         frog       0.78      0.97      0.87      1000
#        horse       0.90      0.92      0.91      1000
#         ship       0.94      0.93      0.94      1000
#        truck       0.87      0.95      0.91      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
#
# 🔍 Key Observations:
# - Model achieved strong performance with overall accuracy close to 90%.
# - Best performing classes: Automobile, Ship, Horse.
# - Weakest performance observed in Cat and Dog due to visual similarities.
# - Balanced performance across other categories indicates robust learning.
#
# ✅ Conclusion:
# This CNN model demonstrates effective feature extraction and classification for the CIFAR-10 dataset, achieving reliable accuracy and generalization. Further improvements could involve data augmentation, deeper architectures like ResNet, or transfer learning for better fine-grained recognition.
# ==================================================
# 🎯 Project Completed Successfully!
